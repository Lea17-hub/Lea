# %%
ice_cream_rating = 10
sleeping_rating = 10

# %%
first_name = input()
last_name = input()
myname = first_name + '' + last_name
# Out:
#  Lea
#  Li

# %%
happiness_rating = (ice_cream_rating+sleeping_rating)*1/2
print(happiness_rating)
# Out:
# 10.0

# %%
print(type(ice_cream_rating))
print(type(first_name))
print(type(happiness_rating))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# Because I have used average function on happiness_rating, so it has type float.

# %%
print('My name is' + myname + 'and I gice eating ice cream a score of '+ str(ice_cream_rating) + ' out of 10.' )
# Out:
# My name isLeaLiand I gice eating ice cream a score of 10 out of 10.
